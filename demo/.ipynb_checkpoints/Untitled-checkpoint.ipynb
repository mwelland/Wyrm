# %%
from sys import path
path.append("../../") # go to parent dir
import thermo_potentials as tp

# %%
#import binary_2phase_elastic
#binary_2phase_elastic.build_potential()
# Out:
# Variables
# ['V_a', 'V_b', 'c0_a', 'c0_b', 'c1_a', 'c1_b']
#
# Potential
#      ⎛          ⎛    c₀ ₐ   ⎞       ⎞                   ⎛    c_0_b    ⎞
# c₀ ₐ⋅⎜2494.2⋅log⎜───────────⎟ + 2500⎟ + 2494.2⋅c_0_b⋅log⎜─────────────⎟ + 2494
#      ⎝          ⎝c₀ ₐ + c₁ ₐ⎠       ⎠                   ⎝c_0_b + c_1_b⎠
#
#            ⎛    c₁ ₐ   ⎞         ⎛          ⎛    c_1_b    ⎞       ⎞
# .2⋅c₁ ₐ⋅log⎜───────────⎟ + c_1_b⋅⎜2494.2⋅log⎜─────────────⎟ + 2500⎟ + (500⋅c₀
#            ⎝c₀ ₐ + c₁ ₐ⎠         ⎝          ⎝c_0_b + c_1_b⎠       ⎠
#
#                  2⎛     Vₐ    ⎞                              2⎛     V_b     ⎞
# ₐ + 500⋅c₁ ₐ)⋅log ⎜───────────⎟ + (500⋅c_0_b + 500⋅c_1_b)⋅log ⎜─────────────⎟
#                   ⎝c₀ ₐ + c₁ ₐ⎠                               ⎝c_0_b + c_1_b⎠
#
# Gradient
# ⎡                      ⎛     Vₐ    ⎞                          ⎛     V_b     ⎞
# ⎢1000⋅(c₀ ₐ + c₁ ₐ)⋅log⎜───────────⎟  1000⋅(c_0_b + c_1_b)⋅log⎜─────────────⎟
# ...

# %%
tp.load_potential('binary_2phase_elastic')
# Out:
# /home/mwelland/Models/thermo_potentials/common_systems/../../thermo_potentials
# looking at  /home/mwelland/Models/thermo_potentials/common_systems/../../thermo_potentials/common_systems/binary_2phase_elastic
# /home/mwelland/Models/thermo_potentials/common_systems/../../thermo_potentials/common_systems/binary_2phase_elastic.py
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_52156/1425200769.py in <module>
# ----> 1 tp.load_potential('binary_2phase_elastic')
#
# ~/Models/thermo_potentials/common_systems/../../thermo_potentials/potentials.py in load_potential(file_name)
#     197     for p in search_path:
#     198         print('looking at ', join(p, file_name))
# --> 199         potential = load_or_build_potential_from_file( join(p, file_name) )
#     200         print(potential)
#     201         if potential is not False:
#
# ...
